# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('cab_rides.csv')
df.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
df.isnull().sum()
# Out:
# START_DATE*      0
# END_DATE*        0
# CATEGORY*        0
# START*           0
# STOP*            0
# MILES*           0
# PURPOSE*       502
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x='CATEGORY*',y='MILES*',data=df)
# Out:
# <AxesSubplot:xlabel='CATEGORY*', ylabel='MILES*'>

# %%
sns.countplot(x='CATEGORY*',data=df)
# Out:
# <AxesSubplot:xlabel='CATEGORY*', ylabel='count'>

# %%
df['CATEGORY*'].value_counts()
# Out:
# Business    1078
# Personal      77
# Name: CATEGORY*, dtype: int64

# %%
df['PURPOSE*'].value_counts()
# Out:
# Meeting            187
# Meal/Entertain     160
# Errand/Supplies    128
# Customer Visit     101
# Temporary Site      50
# Between Offices     18
# Moving               4
# Airport/Travel       3
# Commute              1
# Charity ($)          1
# Name: PURPOSE*, dtype: int64

# %%
df.columns
# Out:
# Index(['START_DATE*', 'END_DATE*', 'CATEGORY*', 'START*', 'STOP*', 'MILES*',
#        'PURPOSE*'],
#       dtype='object')

# %%
df['START*'].value_counts()
# Out:
# Cary                          201
# Unknown Location              148
# Morrisville                    85
# Whitebridge                    68
# Islamabad                      57
#                              ...
# Soho                            1
# Katunayake                      1
# Townes at Everett Crossing      1
# North Berkeley Hills            1
# Florence                        1
# Name: START*, Length: 177, dtype: int64

# %%
df['STOP*'].value_counts()
# Out:
# Cary                203
# Unknown Location    149
# Morrisville          84
# Whitebridge          65
# Islamabad            58
#                    ...
# Farmington Woods      1
# Soho                  1
# Umstead               1
# Tudor City            1
# Florence              1
# Name: STOP*, Length: 188, dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
import datetime 
df['START_DATE*']=df['START_DATE*'].apply(lambda x: datetime.datetime.strptime(x,'%m/%d/%Y %H:%M'))

# %%
import datetime 
df['END_DATE*']=df['END_DATE*'].apply(lambda x: datetime.datetime.strptime(x,'%m/%d/%Y %H:%M'))

# %%
df
# Out:
#              START_DATE*           END_DATE* CATEGORY*            START*  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  Business       Fort Pierce
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  Business       Fort Pierce
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  Business       Fort Pierce
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business       Fort Pierce
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# ...                  ...                 ...       ...               ...
# 1150 2016-12-31 01:07:00 2016-12-31 01:14:00  Business           Kar?chi
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  Business           Kar?chi
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  Business        Katunayake
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# ...

# %%
df.groupby([])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-0d5020b2e497> in <module>
# ----> 1 df.groupby([])
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6509         axis = self._get_axis_number(axis)
#    6510
# -> 6511         return DataFrameGroupBy(
#    6512             obj=self,
#    6513             keys=by,
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     523             from pandas.core.groupby.grouper import get_grouper
#     524
# --> 525             grouper, exclusions, obj = get_grouper(
#     526                 obj,
#     527                 keys,
#
# ...

# %%
fig = plt.figure(figsize = (15,30))

sns.countplot(y='START*',data=df)
# Out:
# <AxesSubplot:xlabel='count', ylabel='START*'>

# %%
df2=pd.read_csv('cab_rides.csv')

# %%
df2
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...                ...               ...       ...               ...
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*
# 0          Fort Pierce     5.1   Meal/Entertain
# ...

# %%
df['START*']=='Unknown Location'
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1150    False
# 1151    False
# 1152     True
# 1153    False
# 1154    False
# Name: START*, Length: 1155, dtype: bool

# %%
fig = plt.figure(figsize = (15,30))

df.groupby(['START*'])[['START_DATE*','MILES*']].sum().plot(kind = 'bar',figsize=(30,10))
# Out:
# <AxesSubplot:xlabel='START*'>

# %%
df['month'] = df['START_DATE*'].dt.month

# %%
df
# Out:
#              START_DATE*           END_DATE* CATEGORY*            START*  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  Business       Fort Pierce
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  Business       Fort Pierce
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  Business       Fort Pierce
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business       Fort Pierce
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# ...                  ...                 ...       ...               ...
# 1150 2016-12-31 01:07:00 2016-12-31 01:14:00  Business           Kar?chi
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  Business           Kar?chi
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  Business        Katunayake
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*  month
# ...

# %%
df.groupby(['month'])[['MILES*']].sum().plot(kind = 'bar',figsize=(10,5))  # in this graph we showing how many miles cover within a month
# Out:
# <AxesSubplot:xlabel='month'>

# %%
df['hour']=df['START_DATE*'].dt.hour
df
# Out:
#              START_DATE*           END_DATE* CATEGORY*            START*  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  Business       Fort Pierce
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  Business       Fort Pierce
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  Business       Fort Pierce
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business       Fort Pierce
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# ...                  ...                 ...       ...               ...
# 1150 2016-12-31 01:07:00 2016-12-31 01:14:00  Business           Kar?chi
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  Business           Kar?chi
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  Business        Katunayake
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*  month  hour
# ...

# %%
df.groupby(['hour'])[['START*']].count().plot(kind = 'bar',figsize=(20,15))
# Out:
# <AxesSubplot:xlabel='hour'>

# %%
df.groupby(['hour'])[['START*']].count()
# Out:
#       START*
# hour
# 0         19
# 1          5
# 2          2
# 3          3
# 5          4
# 6          4
# 7         13
# 8         35
# 9         51
# 10        65
# 11        72
# 12        77
# 13        94
# 14        89
# 15        98
# 16        88
# 17        95
# 18        94
# 19        68
# 20        71
# 21        51
# 22        31
# 23        26

# %%
df['day']=df['START_DATE*'].dt.day
df
# Out:
#              START_DATE*           END_DATE* CATEGORY*            START*  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  Business       Fort Pierce
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  Business       Fort Pierce
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  Business       Fort Pierce
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business       Fort Pierce
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# ...                  ...                 ...       ...               ...
# 1150 2016-12-31 01:07:00 2016-12-31 01:14:00  Business           Kar?chi
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  Business           Kar?chi
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  Business        Katunayake
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*  month  hour  day
# ...

# %%
df.groupby(['day'])[['START*']].count().plot(kind='bar',figsize=(30,10))
# Out:
# <AxesSubplot:xlabel='day'>

# %%
df.groupby(['day'])[['START*']].count()
# Out:
#      START*
# day
# 1        43
# 2        30
# 3        33
# 4        33
# 5        33
# 6        33
# 7        34
# 8        37
# 9        29
# 10       35
# 11       37
# 12       44
# 13       37
# 14       33
# 15       28
# 16       42
# 17       33
# 18       38
# 19       67
# 20       38
# 21       45
# 22       45
# 23       34
# 24       29
# 25       35
# 26       45
# 27       51
# 28       36
# 29       51
# 30       32
# 31       15

# %%
#freequently booking area , no. of rides booked in morning evening night

# %%
df.groupby(['START*']).count().plot(kind='bar',figsize=(30,10))
# Out:
# <AxesSubplot:xlabel='START*'>

# %%
df['START*'].value_counts()
# Out:
# Cary                          201
# Unknown Location              148
# Morrisville                    85
# Whitebridge                    68
# Islamabad                      57
#                              ...
# Soho                            1
# Katunayake                      1
# Townes at Everett Crossing      1
# North Berkeley Hills            1
# Florence                        1
# Name: START*, Length: 177, dtype: int64

# %%
df
# Out:
#              START_DATE*           END_DATE* CATEGORY*            START*  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  Business       Fort Pierce
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  Business       Fort Pierce
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  Business       Fort Pierce
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business       Fort Pierce
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# ...                  ...                 ...       ...               ...
# 1150 2016-12-31 01:07:00 2016-12-31 01:14:00  Business           Kar?chi
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  Business           Kar?chi
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  Business        Katunayake
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*  month  hour  day
# ...

# %%
for i in hour:
    if i>4 or i<12:
        print('morning')
    elif i>12 or i<15:
        print('afternoon')
    elif i>15 or i<19:
        print('evening')
    else:
        print('night')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-d9961d3d5dbd> in <module>
# ----> 1 for i in hour:
#       2     if i>4 or i<12:
#       3         print('morning')
#       4     elif i>12 or i<15:
#       5         print('afternoon')
#
# NameError: name 'hour' is not defined

# %%
df['Period']=df['START_DATE*'].dt.hour.apply(lambda x: 'Morning' if x>=5  and x<12 else 'Afternoon' if x>=12 and x<18  else  'Evening' if x>=18 and x<22  else 'Night' if x>=22 or x<5   else x)

# %%
df
# Out:
#              START_DATE*           END_DATE* CATEGORY*            START*  \
# 0    2016-01-01 21:11:00 2016-01-01 21:17:00  Business       Fort Pierce
# 1    2016-01-02 01:25:00 2016-01-02 01:37:00  Business       Fort Pierce
# 2    2016-01-02 20:25:00 2016-01-02 20:38:00  Business       Fort Pierce
# 3    2016-01-05 17:31:00 2016-01-05 17:45:00  Business       Fort Pierce
# 4    2016-01-06 14:42:00 2016-01-06 15:49:00  Business       Fort Pierce
# ...                  ...                 ...       ...               ...
# 1150 2016-12-31 01:07:00 2016-12-31 01:14:00  Business           Kar?chi
# 1151 2016-12-31 13:24:00 2016-12-31 13:42:00  Business           Kar?chi
# 1152 2016-12-31 15:03:00 2016-12-31 15:38:00  Business  Unknown Location
# 1153 2016-12-31 21:32:00 2016-12-31 21:50:00  Business        Katunayake
# 1154 2016-12-31 22:08:00 2016-12-31 23:51:00  Business           Gampaha
#
#                  STOP*  MILES*         PURPOSE*  month  hour  day     Period
# ...

# %%
df.groupby(['Period']).count().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='Period'>

# %%
df.isnull().sum()
# Out:
# START_DATE*      0
# END_DATE*        0
# CATEGORY*        0
# START*           0
# STOP*            0
# MILES*           0
# PURPOSE*       502
# month            0
# hour             0
# day              0
# Period           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1
